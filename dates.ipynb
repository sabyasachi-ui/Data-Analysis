# %%
from datetime import datetime, timedelta
from openpyxl import Workbook
from openpyxl.styles import Font

# %%
from datetime import datetime, timedelta
from openpyxl import Workbook
from openpyxl.styles import Font
# Define the date range
start_date = datetime(2025, 7, 1)
end_date = datetime(2025, 10, 31)

# Define target weekdays: Monday=0, Wednesday=2, Friday=4
target_weekdays = {0, 1, 3}

# Generate data grouped by month
grouped_data = {}
current_date = start_date
while current_date <= end_date:
    if current_date.weekday() in target_weekdays:
        month_name = current_date.strftime("%B %Y")  # e.g., July 2025
        if month_name not in grouped_data:
            grouped_data[month_name] = []
        grouped_data[month_name].append([
            current_date.strftime("%d-%m-%Y"),
            current_date.strftime("%A")
        ])
    current_date += timedelta(days=1)

# Create Excel workbook and sheet
wb = Workbook()
ws = wb.active
ws.title = "Section-H"

# Write data to Excel with month headers
row_num = 1
for month, dates in grouped_data.items():
    # # Month header
    # ws.cell(row=row_num, column=1, value=month).font = Font(bold=True, size=12)
    # row_num += 1

    # # Column headers
    # ws.cell(row=row_num, column=1, value="Date").font = Font(bold=True)
    # ws.cell(row=row_num, column=2, value="Day").font = Font(bold=True)
    # row_num += 1

    # Date rows
    for date_row in dates:
        ws.cell(row=row_num, column=1, value=date_row[0])
        ws.cell(row=row_num, column=2, value=date_row[1])

    # Blank row between months
    row_num += 1

# Save the file
wb.save("Section-H.xlsx")
print("Section-H.xlsx' has been created.")
# Out:
# Section-H.xlsx' has been created.

# %%
from datetime import datetime, timedelta
from openpyxl import Workbook
from openpyxl.styles import Font

# Define the date range
start_date = datetime(2025, 7, 1)
end_date = datetime(2025, 10, 31)

# Define target weekdays: Monday=0, Tuesday=1, Thursday=3
target_weekdays = {0, 1, 3}

# Mapping weekdays to activity names
activity_map = {
    0: "Theory",
    1: "Project",
    3: "Practice"
}

# Generate data grouped by month
grouped_data = {}
current_date = start_date
while current_date <= end_date:
    if current_date.weekday() in target_weekdays:
        month_name = current_date.strftime("%B %Y")  # e.g., July 2025
        if month_name not in grouped_data:
            grouped_data[month_name] = []
        grouped_data[month_name].append([
            current_date.strftime("%d-%m-%Y"),
            current_date.strftime("%A"),
            activity_map[current_date.weekday()]
        ])
    current_date += timedelta(days=1)

# Create Excel workbook and sheet
wb = Workbook()
ws = wb.active
ws.title = "Section-H"

# Write data to Excel with month headers
row_num = 1
for month, dates in grouped_data.items():
    for date_row in dates:
        ws.cell(row=row_num, column=1, value=date_row[0])  # Date
        ws.cell(row=row_num, column=2, value=date_row[1])  # Day
        ws.cell(row=row_num, column=3, value=date_row[2])  # Activity
        row_num += 1
    row_num += 1  # Blank row between months

# Save the file
wb.save("Section-H.xlsx")
print("Section-H.xlsx has been created.")
# Out:
# Section-H.xlsx has been created.

# %%
from datetime import datetime, timedelta
from openpyxl import Workbook
from openpyxl.styles import Font

# Define the date range
start_date = datetime(2025, 7, 1)
end_date = datetime(2025, 10, 31)

# Define target weekdays: Monday=0, Tuesday=1, Thursday=3
target_weekdays = {0, 1, 3}

# Map weekday numbers to activities
activity_map = {
    0: "pp",
    1: "TUT",
    3: "PR"
}

# Group data by month
grouped_data = {}
current_date = start_date
while current_date <= end_date:
    if current_date.weekday() in target_weekdays:
        month_name = current_date.strftime("%B %Y")  # e.g., July 2025
        if month_name not in grouped_data:
            grouped_data[month_name] = []
        grouped_data[month_name].append([
            current_date.strftime("%d-%m-%Y"),
            current_date.strftime("%A"),
            activity_map[current_date.weekday()]
        ])
    current_date += timedelta(days=1)

# Create Excel workbook and sheet
wb = Workbook()
ws = wb.active
ws.title = "Section-H"

# Write data to Excel
row_num = 1
for month, dates in grouped_data.items():
    # Month header
    ws.cell(row=row_num, column=1, value=month).font = Font(bold=True, size=12)
    row_num += 1

    # Column headers
    ws.cell(row=row_num, column=1, value="Date").font = Font(bold=True)
    ws.cell(row=row_num, column=2, value="Day").font = Font(bold=True)
    ws.cell(row=row_num, column=3, value="Activity").font = Font(bold=True)
    row_num += 1

    # Dates with activity
    for date_row in dates:
        ws.cell(row=row_num, column=1, value=date_row[0])
        ws.cell(row=row_num, column=2, value=date_row[1])
        ws.cell(row=row_num, column=3, value=date_row[2])
        row_num += 1

    # Blank row between months
    row_num += 1

# Save Excel file
wb.save("Section-H.xlsx")
print("Section-H.xlsx has been created with headers and activities.")

# %%
from datetime import datetime, timedelta
from openpyxl import Workbook
from openpyxl.styles import Font


# Define the date range
start_date = datetime(2025, 7, 1)
end_date = datetime(2025, 10, 31)

# Define target weekdays: Monday=0, Tuesday=1, Thursday=3
target_weekdays = {0, 2, 3,4}

# Map weekday numbers to activities
activity_map = {
    0: "PP",
    2: "TUT",
    3: "TUT",
    4: "PR"
}
print("Creating Section-H.xlsx with headers and activities...") 
Sec=input("Enter Section")  # Wait for user input before proceeding


# Group data by month
grouped_data = {}
current_date = start_date
while current_date <= end_date:
    if current_date.weekday() in target_weekdays:
        month_name = current_date.strftime("%B %Y")  # e.g., July 2025
        if month_name not in grouped_data:
            grouped_data[month_name] = []
        grouped_data[month_name].append([
            current_date.strftime("%d-%m-%Y"),
            current_date.strftime("%A"),
            activity_map[current_date.weekday()]
        ])
    current_date += timedelta(days=1)

# Create Excel workbook and sheet
wb = Workbook()
ws = wb.active
ws.title = f"Section-{Sec}"  # Use the user input for the section title

# Write data to Excel
row_num = 1
for month, dates in grouped_data.items():
    # Month header
    ws.cell(row=row_num, column=1, value=month).font = Font(bold=True, size=12)
    row_num += 1

    # Column headers
    ws.cell(row=row_num, column=2, value="Activity").font = Font(bold=True)
    ws.cell(row=row_num, column=3, value="Date").font = Font(bold=True)
    ws.cell(row=row_num, column=4, value="Day").font = Font(bold=True)
    
    row_num += 1

    # Dates with activity
    for date_row in dates:
        # Write date, day, and activity
        ws.cell(row=row_num, column=2, value=date_row[2])
        ws.cell(row=row_num, column=3, value=date_row[0])
        ws.cell(row=row_num, column=4, value=date_row[1])
        
        row_num += 1

    # Blank row between months
    row_num += 1

# Save Excel file
try:
    wb.save(f"Section-{Sec}.xlsx")
    print(f"Section-{Sec}.xlsx has been created with headers and activities.")
except PermissionError:
    print(f"Permission denied: Please close '{f'Section-{Sec}.xlsx'}' if it is open and try again.")
# Out:
# Creating Section-H.xlsx with headers and activities...
# Section-E.xlsx has been created with headers and activities.

# %%
from datetime import datetime, timedelta
from openpyxl import Workbook
from openpyxl.styles import Font


# Define the date range
start_date = datetime(2025, 7, 1)
end_date = datetime(2025, 10, 31)

# Define target weekdays: Monday=0, Tuesday=1, Thursday=3
target_weekdays = {0,1, 2, 3,4}

# Map weekday numbers to activities
activity_map = {
    0: "PP",   # Added mapping for Monday
    1: "PP",   # Tuesday
    2: "TUT",  # Wednesday
    3: "TUT",  # Thursday
    4: "PR"    # Friday
}
print("Creating Section with headers and activities...") 
Sec=input("Enter Section")  # Wait for user input before proceeding


# Group data by month
grouped_data = {}
current_date = start_date
while current_date <= end_date:
    if current_date.weekday() in target_weekdays:
        month_name = current_date.strftime("%B %Y")  # e.g., July 2025
        if month_name not in grouped_data:
            grouped_data[month_name] = []
        grouped_data[month_name].append([
            current_date.strftime("%Y-%m-%d"),
            current_date.strftime("%A"),
            activity_map[current_date.weekday()]
        ])
    current_date += timedelta(days=1)

# Create Excel workbook and sheet
wb = Workbook()
ws = wb.active
ws.title = f"Section-{Sec}"  # Use the user input for the section title

# Write data to Excel
row_num = 1
for month, dates in grouped_data.items():
    # Month header
    ws.cell(row=row_num, column=1, value=month).font = Font(bold=True, size=12)
    row_num += 1

    # Column headers
    ws.cell(row=row_num, column=2, value="Activity").font = Font(bold=True)
    ws.cell(row=row_num, column=3, value="Date").font = Font(bold=True)
    ws.cell(row=row_num, column=4, value="Day").font = Font(bold=True)
    
    row_num += 1

    # Dates with activity
    for date_row in dates:
        # Write date, day, and activity
        ws.cell(row=row_num, column=2, value=date_row[2])
        ws.cell(row=row_num, column=3, value=date_row[0])
        ws.cell(row=row_num, column=4, value=date_row[1])
        
        row_num += 1

    # Blank row between months
    row_num += 1

# Save Excel file
try:
    wb.save(f"Section-{Sec}.xlsx")
    print(f"Section-{Sec}.xlsx has been created with headers and activities.")
except PermissionError:
    print(f"Permission denied: Please close '{f'Section-{Sec}.xlsx'}' if it is open and try again.")
# Out:
# Creating Section with headers and activities...
# Section-c.xlsx has been created with headers and activities.
